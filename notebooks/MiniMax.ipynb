# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# board = np.zeros([3,3])
board = np.sign(np.random.randn(3,3))
plt.figure()
plt.imshow(board,cmap = 'bone')
plt.xticks([])
plt.yticks([])
plt.show()

def b2v(board):
    return board.reshape(-1)

def v2b(v):
    return v.reshape(3,3)

# %%
eg = []
eg.append(np.identity(3))
eg.append(np.fliplr(eg[-1]))
eg.append(np.array([[1,1,1],[0,0,0],[0,0,0]]))
eg.append(np.roll(eg[-1],1,axis=0))
eg.append(np.roll(eg[-1],1,axis=0))
eg.append(eg[-3].T)
eg.append(eg[-3].T)
eg.append(eg[-3].T)

for i in eg:
    plt.figure(figsize = (0.5,0.5))
    plt.imshow(i,cmap='bone')
    plt.xticks([])
    plt.yticks([])
    plt.show()
for i in range(len(eg)):
    eg[i] = b2v(eg[i])
eg = np.array(eg).T

board = np.zeros([3,3])
# board = np.sign(np.random.randn(3,3))

def prop_mvs(v):
    return np.where(v==0)[0]
    
def fin(v):
    score = np.dot(v,eg)
    ind = np.argmax(np.abs(score))
    
    if np.abs(score[ind])!=3:
        return 0
    else: 
        return np.sign(score[ind])

# %%
done = False
while done == False:
    board = np.sign(np.random.randn(3,3))
    res = fin(b2v(board))
    if np.abs(res) == 1.0:
        plt.figure()
        plt.imshow(board,cmap='bone')
        plt.xticks([])
        plt.yticks([])
        plt.show()
        print(res)
        done = True
# Out:
# 1.0

# %%
# board: np.array [3,3]

def b2v(board):
    """convert board from 2d representation into 1 d representation"""
    return board.reshape(-1)

def v2b(v: np.array):
    """Convert board from vector into 2d representation"""
    return v.reshape(3,3)

def prop_mvs(v):
    """proposed moves, using the 1d represntation"""
    return np.where(v==0)[0]

eg = []
eg.append(np.identity(3))
eg.append(np.fliplr(eg[-1]))
eg.append(np.array([[1,1,1],[0,0,0],[0,0,0]]))
eg.append(np.roll(eg[-1],1,axis=0))
eg.append(np.roll(eg[-1],1,axis=0))
eg.append(eg[-3].T)
eg.append(eg[-3].T)
eg.append(eg[-3].T)
    
def fin(v):
    """is the game over?"""
    score = np.dot(v,eg)
    ind = np.argmax(np.abs(score))
    
    if np.abs(score[ind])!=3:
        return 0
    else: 
        return np.sign(score[ind])
    

def gm(board, player='x'):
    """given the current board give the best move using min max trees """
    sgn = 1
    if player != 'x':
        sgn = -1
    v = b2v(board)
    mvs = prop_mvs(v)
    opts = []
    bds = []
    for i in mvs:
        bds.append(np.copy(v))
        bds[-1][i] = sgn
    for i in range(len(bds)):
        tree = []
        outs = []

    tree.append([bds[i]])
    while len(tree) != 0:
        while len(tree[-1]) != 0:
            out = fin(tree[-1][-1])
            mvs = prop_mvs(tree[-1][-1])
            if np.abs(out)==1:
                outs.append(out)
                tree[-1].pop(-1)            
            elif len(mvs) == 0:
                outs.append(out)
                tree[-1].pop(-1)
            else:
                next = []
                for i in tree[]:
                    pass

            # Expand
          tree.append()
          print(mvs)
      # Go up one layer:
      tree.pop(-1)
      sgn = sgn * -1  
    

board = np.sign(np.random.randn(3,3)).astype(int)+1

print(gm(board))
# Out:
#   File "<ipython-input-38-c8317615f83e>", line 11
#     """given the current board give the best move using min max trees """
#                                                                          ^
# SyntaxError: invalid syntax

# %%
cboard = np.sign(np.random.randn(3,3)).astype(int)+1
prop_mvs(b2v(board)).shape
# Out:
# (5,)

# %%
board = np.sign(np.random.randn(3,3))
board
# Out:
# array([[-1., -1., -1.],
#        [-1., -1., -1.],
#        [ 1., -1., -1.]])
